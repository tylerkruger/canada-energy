# %%
import os
import pandas as pd

os.chdir("/Users/tylerkruger/Desktop/projects/canada-energy")

# %%
df = pd.read_csv("data/raw/energy-production/ab_production.csv")
df2 = pd.read_csv("data/raw/energy-production/nwt_production.csv")

# %%
df.head()

df2.head()

# %%
files = Path("data/raw/energy-production").glob("*.csv")

dfs = []

for f in files:
    df = pd.read_csv(f)
    dfs.append(df)

energy = pd.concat(dfs)

energy.head()

# %%
os.getcwd()
# Out:
# '/Users/tylerkruger/Desktop/projects/canada-energy'

# %%
df = pd.read_csv("data/raw/energy-production/alberta_production.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df = pd.read_csv("data/raw/energy-production/alberta_production.csv")
#
# File ~/Desktop/projects/canada-energy/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...
